# %%
import geopandas as gpd

# %%
census = gpd.read_file('../../data/CensusTract/census_tract_2012.shp')

# %%
type(census)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
census.head(10)
# Out:
#                             slug                   set                 kind  \
# 0  06037101110-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 1  06037101122-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 2  06037101210-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 3  06037101220-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 4  06037101300-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 5  06037101400-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 6  06037102103-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 7  06037102104-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 8  06037102105-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 9  06037102107-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
#
#     external_i     name                       display_na     INTPTLAT NAME_1  \
# ...

# %%
census.tail(10)
# Out:
#                                slug                   set  \
# 2336  06037980024-census-tract-2012  Census Tracts (2012)
# 2337  06037980025-census-tract-2012  Census Tracts (2012)
# 2338  06037980026-census-tract-2012  Census Tracts (2012)
# 2339  06037980028-census-tract-2012  Census Tracts (2012)
# 2340  06037980030-census-tract-2012  Census Tracts (2012)
# 2341  06037980031-census-tract-2012  Census Tracts (2012)
# 2342  06037980033-census-tract-2012  Census Tracts (2012)
# 2343  06037990100-census-tract-2012  Census Tracts (2012)
# 2344  06037990200-census-tract-2012  Census Tracts (2012)
# 2345  06037990300-census-tract-2012  Census Tracts (2012)
#
#                      kind   external_i     name  \
# 2336  Census Tract (2012)  06037980024  9800.24
# 2337  Census Tract (2012)  06037980025  9800.25
# 2338  Census Tract (2012)  06037980026  9800.26
# 2339  Census Tract (2012)  06037980028  9800.28
# 2340  Census Tract (2012)  06037980030  9800.30
# ...

# %%
census.sample(10)
# Out:
#                                slug                   set  \
# 1718  06037543802-census-tract-2012  Census Tracts (2012)
# 225   06037127606-census-tract-2012  Census Tracts (2012)
# 1090  06037401703-census-tract-2012  Census Tracts (2012)
# 1248  06037408504-census-tract-2012  Census Tracts (2012)
# 1382  06037463601-census-tract-2012  Census Tracts (2012)
# 864   06037267501-census-tract-2012  Census Tracts (2012)
# 2183  06037900606-census-tract-2012  Census Tracts (2012)
# 2102  06037670701-census-tract-2012  Census Tracts (2012)
# 905   06037273200-census-tract-2012  Census Tracts (2012)
# 2023  06037609900-census-tract-2012  Census Tracts (2012)
#
#                      kind   external_i     name  \
# 1718  Census Tract (2012)  06037543802  5438.02
# 225   Census Tract (2012)  06037127606  1276.06
# 1090  Census Tract (2012)  06037401703  4017.03
# 1248  Census Tract (2012)  06037408504  4085.04
# 1382  Census Tract (2012)  06037463601  4636.01
# ...

# %%
census.dtypes
# Out:
# slug            object
# set             object
# kind            object
# external_i      object
# name            object
# display_na      object
# INTPTLAT        object
# NAME_1          object
# INTPTLON        object
# FUNCSTAT        object
# GEOID           object
# AWATER          object
# COUNTYFP        object
# NAMELSAD        object
# MTFCC           object
# TRACTCE         object
# STATEFP         object
# ALAND           object
# geometry      geometry
# dtype: object

# %%
census.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   slug        2346 non-null   object
#  1   set         2346 non-null   object
#  2   kind        2346 non-null   object
#  3   external_i  2346 non-null   object
#  4   name        2346 non-null   object
#  5   display_na  2346 non-null   object
#  6   INTPTLAT    2346 non-null   object
#  7   NAME_1      0 non-null      object
#  8   INTPTLON    2346 non-null   object
#  9   FUNCSTAT    2346 non-null   object
#  10  GEOID       2346 non-null   object
#  11  AWATER      2346 non-null   object
#  12  COUNTYFP    2346 non-null   object
#  13  NAMELSAD    2346 non-null   object
#  14  MTFCC       2346 non-null   object
#  15  TRACTCE     2346 non-null   object
#  16  STATEFP     2346 non-null   object
#  17  ALAND       2346 non-null   object
# ...

# %%
census.shape
# Out:
# (2346, 19)

# %%
census.columns.to_list()
# Out:
# ['slug',
#  'set',
#  'kind',
#  'external_i',
#  'name',
#  'display_na',
#  'INTPTLAT',
#  'NAME_1',
#  'INTPTLON',
#  'FUNCSTAT',
#  'GEOID',
#  'AWATER',
#  'COUNTYFP',
#  'NAMELSAD',
#  'MTFCC',
#  'TRACTCE',
#  'STATEFP',
#  'ALAND',
#  'geometry']

# %%
census['ALAND']
# Out:
# 0        1142405
# 1        2644042
# 2         650691
# 3         698969
# 4        2581129
#           ...
# 2341    12598244
# 2342    12678792
# 2343           0
# 2344           0
# 2345           0
# Name: ALAND, Length: 2346, dtype: object

# %%
# another way
census.ALAND
# Out:
# 0        1142405
# 1        2644042
# 2         650691
# 3         698969
# 4        2581129
#           ...
# 2341    12598244
# 2342    12678792
# 2343           0
# 2344           0
# 2345           0
# Name: ALAND, Length: 2346, dtype: object

# %% [markdown]
# But what if you want to know how many stations there are for each line?

# %%
census['ALAND'].value_counts()
# Out:
# 0           3
# 340750      2
# 659020      2
# 989257      2
# 1679001     2
#            ..
# 16136088    1
# 766374      1
# 645672      1
# 1083979     1
# 2184453     1
# Name: ALAND, Length: 2340, dtype: int64

# %%
census['ALAND'].value_counts().plot.bar()

# %%
census.ALAND.value_counts().plot.bar()

# %%
desired_columns = ['GEOID','name','TRACTCE','geometry']

census[desired_columns]
# Out:
#             GEOID     name TRACTCE  \
# 0     06037101110  1011.10  101110
# 1     06037101122  1011.22  101122
# 2     06037101210  1012.10  101210
# 3     06037101220  1012.20  101220
# 4     06037101300     1013  101300
# ...           ...      ...     ...
# 2341  06037980031  9800.31  980031
# 2342  06037980033  9800.33  980033
# 2343  06037990100     9901  990100
# 2344  06037990200     9902  990200
# 2345  06037990300     9903  990300
#
#                                                geometry
# 0     POLYGON ((-118.30229 34.25870, -118.30079 34.2...
# 1     POLYGON ((-118.30333 34.27354, -118.30318 34.2...
# 2     POLYGON ((-118.29945 34.25598, -118.28592 34.2...
# 3     POLYGON ((-118.28592 34.24896, -118.28592 34.2...
# 4     POLYGON ((-118.27247 34.23253, -118.27194 34.2...
# ...                                                 ...
# 2341  POLYGON ((-118.28530 33.70860, -118.28337 33.7...
# 2342  POLYGON ((-118.24463 33.71077, -118.23180 33.7...
# ...

# %%
census.head()
# Out:
#                             slug                   set                 kind  \
# 0  06037101110-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 1  06037101122-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 2  06037101210-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 3  06037101220-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 4  06037101300-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
#
#     external_i     name                       display_na     INTPTLAT NAME_1  \
# 0  06037101110  1011.10  06037101110 Census Tract (2012)  +34.2594737   None
# 1  06037101122  1011.22  06037101122 Census Tract (2012)  +34.2677213   None
# 2  06037101210  1012.10  06037101210 Census Tract (2012)  +34.2529724   None
# 3  06037101220  1012.20  06037101220 Census Tract (2012)  +34.2516085   None
# 4  06037101300     1013  06037101300 Census Tract (2012)  +34.2487732   None
#
# ...

# %%
census_trimmed = census[desired_columns]
census_trimmed
# Out:
#             GEOID     name TRACTCE  \
# 0     06037101110  1011.10  101110
# 1     06037101122  1011.22  101122
# 2     06037101210  1012.10  101210
# 3     06037101220  1012.20  101220
# 4     06037101300     1013  101300
# ...           ...      ...     ...
# 2341  06037980031  9800.31  980031
# 2342  06037980033  9800.33  980033
# 2343  06037990100     9901  990100
# 2344  06037990200     9902  990200
# 2345  06037990300     9903  990300
#
#                                                geometry
# 0     POLYGON ((-118.30229 34.25870, -118.30079 34.2...
# 1     POLYGON ((-118.30333 34.27354, -118.30318 34.2...
# 2     POLYGON ((-118.29945 34.25598, -118.28592 34.2...
# 3     POLYGON ((-118.28592 34.24896, -118.28592 34.2...
# 4     POLYGON ((-118.27247 34.23253, -118.27194 34.2...
# ...                                                 ...
# 2341  POLYGON ((-118.28530 33.70860, -118.28337 33.7...
# 2342  POLYGON ((-118.24463 33.71077, -118.23180 33.7...
# ...

# %%
census_trimmed.geometry
# Out:
# 0       POLYGON ((-118.30229 34.25870, -118.30079 34.2...
# 1       POLYGON ((-118.30333 34.27354, -118.30318 34.2...
# 2       POLYGON ((-118.29945 34.25598, -118.28592 34.2...
# 3       POLYGON ((-118.28592 34.24896, -118.28592 34.2...
# 4       POLYGON ((-118.27247 34.23253, -118.27194 34.2...
#                               ...
# 2341    POLYGON ((-118.28530 33.70860, -118.28337 33.7...
# 2342    POLYGON ((-118.24463 33.71077, -118.23180 33.7...
# 2343    POLYGON ((-118.95114 33.99643, -118.95056 34.0...
# 2344    POLYGON ((-118.63168 34.00001, -118.63598 34.0...
# 2345    POLYGON ((-118.48228 33.74869, -118.47656 33.7...
# Name: geometry, Length: 2346, dtype: geometry

# %%
census_trimmed.head()
# Out:
#          GEOID     name TRACTCE  \
# 0  06037101110  1011.10  101110
# 1  06037101122  1011.22  101122
# 2  06037101210  1012.10  101210
# 3  06037101220  1012.20  101220
# 4  06037101300     1013  101300
#
#                                             geometry
# 0  POLYGON ((-118.30229 34.25870, -118.30079 34.2...
# 1  POLYGON ((-118.30333 34.27354, -118.30318 34.2...
# 2  POLYGON ((-118.29945 34.25598, -118.28592 34.2...
# 3  POLYGON ((-118.28592 34.24896, -118.28592 34.2...
# 4  POLYGON ((-118.27247 34.23253, -118.27194 34.2...

# %%
# what is the projection?
census_trimmed.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
census_gcs = census_trimmed.to_crs("EPSG:4326")

# %%
for index, row in census_gcs.iterrows():
    print(row.GEOID)
# Out:
# 06037101110
# 06037101122
# 06037101210
# 06037101220
# 06037101300
# 06037101400
# 06037102103
# 06037102104
# 06037102105
# 06037102107
# 06037103101
# 06037103102
# 06037103200
# 06037103300
# 06037103400
# 06037104103
# 06037104105
# 06037104108
# 06037104124
# 06037104201
# 06037104203
# 06037104204
# 06037104310
# 06037104320
# 06037104401
# 06037104403
# 06037104404
# 06037104500
# 06037104610
# 06037104620
# 06037104701
# 06037104703
# 06037104704
# 06037104810
# 06037104821
# 06037104822
# 06037106010
# 06037106020
# 06037106111
# 06037106112
# 06037106113
# 06037106114
# 06037106403
# 06037106405
# 06037106406
# 06037106407
# 06037106408
# 06037106510
# 06037106520
# 06037106603
# 06037106604
# 06037106641
# 06037106642
# 06037106643
# 06037106645
# 06037106646
# 06037106648
# 06037106649
# 06037107010
# 06037107020
# 06037108101
# 06037108102
# 06037108103
# 06037108104
# 06037108201
# 06037108202
# 06037109100
# 06037109200
# 06037109300
# 06037109400
# 06037109500
# ...

# %%
for index, row in census_gcs.iterrows():
    print(row.GEOID)
# Out:
# 06037101110
# 06037101122
# 06037101210
# 06037101220
# 06037101300
# 06037101400
# 06037102103
# 06037102104
# 06037102105
# 06037102107
# 06037103101
# 06037103102
# 06037103200
# 06037103300
# 06037103400
# 06037104103
# 06037104105
# 06037104108
# 06037104124
# 06037104201
# 06037104203
# 06037104204
# 06037104310
# 06037104320
# 06037104401
# 06037104403
# 06037104404
# 06037104500
# 06037104610
# 06037104620
# 06037104701
# 06037104703
# 06037104704
# 06037104810
# 06037104821
# 06037104822
# 06037106010
# 06037106020
# 06037106111
# 06037106112
# 06037106113
# 06037106114
# 06037106403
# 06037106405
# 06037106406
# 06037106407
# 06037106408
# 06037106510
# 06037106520
# 06037106603
# 06037106604
# 06037106641
# 06037106642
# 06037106643
# 06037106645
# 06037106646
# 06037106648
# 06037106649
# 06037107010
# 06037107020
# 06037108101
# 06037108102
# 06037108103
# 06037108104
# 06037108201
# 06037108202
# 06037109100
# 06037109200
# 06037109300
# 06037109400
# 06037109500
# ...

# %%
for index, row in census_gcs.iterrows():
    print(row.GEOID,row.TRACTCE)
# Out:
# 06037101110 101110
# 06037101122 101122
# 06037101210 101210
# 06037101220 101220
# 06037101300 101300
# 06037101400 101400
# 06037102103 102103
# 06037102104 102104
# 06037102105 102105
# 06037102107 102107
# 06037103101 103101
# 06037103102 103102
# 06037103200 103200
# 06037103300 103300
# 06037103400 103400
# 06037104103 104103
# 06037104105 104105
# 06037104108 104108
# 06037104124 104124
# 06037104201 104201
# 06037104203 104203
# 06037104204 104204
# 06037104310 104310
# 06037104320 104320
# 06037104401 104401
# 06037104403 104403
# 06037104404 104404
# 06037104500 104500
# 06037104610 104610
# 06037104620 104620
# 06037104701 104701
# 06037104703 104703
# 06037104704 104704
# 06037104810 104810
# 06037104821 104821
# 06037104822 104822
# 06037106010 106010
# 06037106020 106020
# 06037106111 106111
# 06037106112 106112
# 06037106113 106113
# 06037106114 106114
# 06037106403 106403
# 06037106405 106405
# 06037106406 106406
# 06037106407 106407
# 06037106408 106408
# ...
